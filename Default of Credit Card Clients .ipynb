# %%
import os, random
import numpy as np
import pandas as pd
from pathlib import Path

# %%
# Repro
SEED = 42
random.seed(SEED); np.random.seed(SEED); os.environ["PYTHONHASHSEED"] = str(SEED)

# ========= 1) Load =========
CSV_PATH = Path("UCI_Credit_Card.csv")
df = pd.read_csv(CSV_PATH)
if "default.payment.next.month" in df.columns:
    df = df.rename(columns={"default.payment.next.month": "target"})
df["target"] = df["target"].astype(int)

# %%
# ========= 2) Feature Engineering =========

bill_cols = [f"BILL_AMT{i}" for i in range(1, 7)]
pay_cols  = [f"PAY_AMT{i}"  for i in range(1, 7)]
paystat   = [f"PAY_{i}"     for i in range(0, 7)]  # PAY_0..PAY_6

def slog1p(x):
    import numpy as np
    return np.sign(x) * np.log1p(np.abs(x))

def engineer_features(frame: pd.DataFrame) -> pd.DataFrame:
    X = frame.copy()

    # --- Utilization & Pay ratio (per month) ---
    for i in range(1, 7):
        X[f"util_{i}"] = (X[f"BILL_AMT{i}"] / X["LIMIT_BAL"]) \
            .replace([np.inf, -np.inf], 0.0).fillna(0.0).clip(0, 5)
        denom = X[f"BILL_AMT{i}"].abs().clip(lower=1.0)
        X[f"pay_ratio_{i}"] = (X[f"PAY_AMT{i}"] / denom).clip(0, 5)

    util_cols = [f"util_{i}" for i in range(1,7)]
    payr_cols = [f"pay_ratio_{i}" for i in range(1,7)]

    # --- Level & dispersion ---
    X["bill_mean"] = X[bill_cols].mean(axis=1)
    X["bill_std"]  = X[bill_cols].std(axis=1).fillna(0.0)
    X["pay_mean"]  = X[pay_cols].mean(axis=1)
    X["pay_std"]   = X[pay_cols].std(axis=1).fillna(0.0)

    # --- Trends (recent minus past) ---
    X["bill_trend_1_3"] = X["BILL_AMT1"] - X["BILL_AMT3"]
    X["bill_trend_1_6"] = X["BILL_AMT1"] - X["BILL_AMT6"]
    X["pay_trend_1_3"]  = X["PAY_AMT1"] - X["PAY_AMT3"]
    X["pay_trend_1_6"]  = X["PAY_AMT1"] - X["PAY_AMT6"]

    # --- Payment gaps (unpaid part) ---
    for i in range(1,7):
        X[f"gap_{i}"] = (X[f"BILL_AMT{i}"] - X[f"PAY_AMT{i}"]).clip(lower=0)
    gap_cols = [f"gap_{i}" for i in range(1,7)]
    X["gap_mean"]       = X[gap_cols].mean(axis=1)
    X["gap_ratio_mean"] = (X["gap_mean"] / X["LIMIT_BAL"]) \
        .replace([np.inf,-np.inf],0).fillna(0.0).clip(0,5)

    # --- Aggregates & consistency ---
    X["util_mean"]       = X[util_cols].mean(axis=1)
    X["util_var"]        = X[util_cols].var(axis=1).fillna(0.0)
    X["pay_ratio_mean"]  = X[payr_cols].mean(axis=1)
    X["pay_ratio_var"]   = X[payr_cols].var(axis=1).fillna(0.0)
    X["max_util"]        = X[util_cols].max(axis=1)
    X["recent_util_mean"]= X[["util_1","util_2"]].mean(axis=1)
    X["old_util_mean"]   = X[["util_5","util_6"]].mean(axis=1)
    X["util_recent_vs_old"] = X["recent_util_mean"] - X["old_util_mean"]

    X["recent_payr_mean"]= X[["pay_ratio_1","pay_ratio_2"]].mean(axis=1)
    X["old_payr_mean"]   = X[["pay_ratio_5","pay_ratio_6"]].mean(axis=1)
    X["payr_recent_vs_old"] = X["recent_payr_mean"] - X["old_payr_mean"]

    X["total_bill"]      = X[bill_cols].sum(axis=1)
    X["total_pay"]       = X[pay_cols].sum(axis=1)
    X["total_pay_ratio"] = (X["total_pay"] / X["total_bill"].abs().clip(lower=1.0)).clip(0, 5)
    X["pay_over_limit"]  = (X["total_pay"] / X["LIMIT_BAL"].clip(lower=1.0)).clip(0, 5)

    # --- Delinquency flags ---
    # handle cases where some PAY_* columns (e.g., PAY_1) may be missing
    pay_present = [c for c in paystat if c in X.columns]
    if len(pay_present) > 0:
        X["max_delinq"] = X[pay_present].max(axis=1)
        X["late_any"] = (X[pay_present].gt(0).any(axis=1)).astype(int)
        X["severe_delinqu"] = (X[pay_present].ge(2).any(axis=1)).astype(int)
        X["num_late"] = (X[pay_present].gt(0).sum(axis=1))
        X["num_severe"] = (X[pay_present].ge(2).sum(axis=1))
        X["delinq_sum_pos"] = X[pay_present].clip(lower=0).sum(axis=1)
    else:
        # fallback defaults (no PAY_* columns at all)
        X["max_delinq"] = 0
        X["late_any"] = 0
        X["severe_delinqu"] = 0
        X["num_late"] = 0
        X["num_severe"] = 0
        X["delinq_sum_pos"] = 0

    # late_recent depends specifically on PAY_0
    if "PAY_0" in X.columns:
        X["late_recent"] = (X["PAY_0"] > 0).astype(int)
    else:
        X["late_recent"] = 0

    # สะสมความล่าช้าแบบถ่วงน้ำหนัก (เดือนล่าสุดสำคัญกว่า)
    # build weighted 3-month late indicator using whatever PAY_0/PAY_1/PAY_2 are present
    X["wlate_3m"] = 0
    if "PAY_0" in X.columns:
        X["wlate_3m"] = X["wlate_3m"] + 3 * (X["PAY_0"] > 0).astype(int)
    if "PAY_1" in X.columns:
        X["wlate_3m"] = X["wlate_3m"] + 2 * (X["PAY_1"] > 0).astype(int)
    if "PAY_2" in X.columns:
        X["wlate_3m"] = X["wlate_3m"] + 1 * (X["PAY_2"] > 0).astype(int)

    # --- Interactions เบา ๆ ---
    X["late_util1"]       = X["late_recent"].astype(int) * X["util_1"]
    X["maxdelinq_util"]   = X["max_delinq"] * X["util_mean"]

    # --- Age bucket (one-hot) ---
    if "AGE" in X.columns:
        X["age_bucket"] = pd.cut(X["AGE"], bins=[0,25,35,45,55,120],
                                 labels=False, include_lowest=True)
        X = pd.get_dummies(X, columns=["age_bucket"], prefix="ageb", dtype=int)

    # --- Sign-preserving log for money variables ---
    money_cols = ["LIMIT_BAL", *bill_cols, *pay_cols, "bill_mean", "pay_mean",
                  "total_bill", "total_pay", *gap_cols, "gap_mean"]
    for c in money_cols:
        X[f"slog_{c}"] = slog1p(X[c])

    # --- Clean-ups ---
    if "ID" in X.columns:
        X = X.drop(columns=["ID"])
    X = X.replace([np.inf, -np.inf], 0.0).fillna(0.0)

    return X


X_all = engineer_features(df.drop(columns=["target"]))
y_all = df["target"].values

# %%
# ========= 3) Split: train/val/test =========
from sklearn.model_selection import train_test_split
X_tr, X_tmp, y_tr, y_tmp = train_test_split(X_all, y_all, test_size=0.20, stratify=y_all, random_state=SEED)
X_va, X_te, y_va, y_te   = train_test_split(X_tmp, y_tmp, test_size=0.50, stratify=y_tmp, random_state=SEED)
# => 80/10/10 split

# %%
# ========= 4) Scale =========
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_tr_sc = scaler.fit_transform(X_tr)
X_va_sc = scaler.transform(X_va)
X_te_sc = scaler.transform(X_te)

# %%
# ========= 5) Class weights (cost-aware) =========
# ตั้งต้นง่าย ๆ: class_weight = {0: C_FP, 1: C_FN}
C_FP, C_FN = 1.0, 10.0
class_weight = {0: C_FP, 1: C_FN}

# %%
# ========= 6) Build MLP =========
import tensorflow as tf
from tensorflow.keras import layers, regularizers, callbacks

input_dim = X_tr_sc.shape[1]

def focal_loss(gamma=2.0, alpha=0.25):
    # Binary focal loss
    def _fl(y_true, y_pred):
        eps = tf.keras.backend.epsilon()
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.clip_by_value(y_pred, eps, 1.0-eps)
        pt = tf.where(tf.equal(y_true, 1), y_pred, 1-y_pred)
        w  = tf.where(tf.equal(y_true, 1), alpha, 1.0-alpha)
        return -tf.reduce_mean(w * tf.pow((1-pt), gamma) * tf.math.log(pt))
    return _fl

# %%
def build_mlp(use_focal=False, l2=1e-4, dropout=0.25):
    inp = layers.Input(shape=(input_dim,))
    
    x = layers.Dense(256, kernel_regularizer=regularizers.l2(l2))(inp) 
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.Dense(128, kernel_regularizer=regularizers.l2(l2))(inp)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(dropout)(x)

    x = layers.Dense(64, kernel_regularizer=regularizers.l2(l2))(inp)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(dropout)(x)

    x = layers.Dense(32, kernel_regularizer=regularizers.l2(l2))(inp)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(dropout)(x)

    out = layers.Dense(1, activation="sigmoid")(x)
    model = tf.keras.Model(inp, out)
    opt = tf.keras.optimizers.Adam(learning_rate=1e-5)
    if use_focal:
        loss = focal_loss(gamma=2.0, alpha=0.35)  # alpha เน้น positive หนักขึ้น
    else:
        loss = tf.keras.losses.BinaryCrossentropy()

    model.compile(optimizer=opt, loss=loss, metrics=[tf.keras.metrics.AUC(curve="ROC", name="AUC"),
                                                     tf.keras.metrics.AUC(curve="PR", name="AUC_PR")])
    return model

# %%
use_focal = True  # ลอง focal ก่อน; ถ้าไม่เสถียร สลับเป็น False
model = build_mlp(use_focal=use_focal, l2=1e-5, dropout=0.30)
model.summary()

cbs = [
    callbacks.EarlyStopping(monitor="val_AUC_PR", mode="max", patience=12, restore_best_weights=True),
    callbacks.ReduceLROnPlateau(monitor="val_AUC_PR", mode="max", factor=0.5, patience=5, min_lr=3e-5, verbose=1)
]

hist = model.fit(
    X_tr_sc, y_tr,
    validation_data=(X_va_sc, y_va),
    epochs=2000, batch_size=512,
    class_weight=class_weight,  # cost-aware in training
    callbacks=cbs, verbose=2
)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 105)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         3,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,553 (13.88 KB)
#  Trainable params: 3,489 (13.63 KB)
#  Non-trainable params: 64 (256.00 B)
# Epoch 1/2000
# 47/47 - 1s - 19ms/step - AUC: 0.5287 - AUC_PR: 0.2372 - loss: 1.1189 - val_AUC: 0.5206 - val_AUC_PR: 0.2392 - val_loss: 0.3849 - learning_rate: 1.0000e-05
# Epoch 2/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5275 - AUC_PR: 0.2393 - loss: 1.1016 - val_AUC: 0.5342 - val_AUC_PR: 0.2441 - val_loss: 0.3520 - learning_rate: 1.0000e-05
# Epoch 3/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5334 - AUC_PR: 0.2409 - loss: 1.0834 - val_AUC: 0.5441 - val_AUC_PR: 0.2486 - val_loss: 0.3327 - learning_rate: 1.0000e-05
# Epoch 4/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5415 - AUC_PR: 0.2430 - loss: 1.0652 - val_AUC: 0.5522 - val_AUC_PR: 0.2529 - val_loss: 0.3199 - learning_rate: 1.0000e-05
# Epoch 5/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5440 - AUC_PR: 0.2442 - loss: 1.0477 - val_AUC: 0.5585 - val_AUC_PR: 0.2563 - val_loss: 0.3098 - learning_rate: 1.0000e-05
# Epoch 6/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5434 - AUC_PR: 0.2459 - loss: 1.0289 - val_AUC: 0.5644 - val_AUC_PR: 0.2594 - val_loss: 0.3018 - learning_rate: 1.0000e-05
# Epoch 7/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5474 - AUC_PR: 0.2474 - loss: 1.0028 - val_AUC: 0.5696 - val_AUC_PR: 0.2616 - val_loss: 0.2951 - learning_rate: 1.0000e-05
# Epoch 8/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5523 - AUC_PR: 0.2500 - loss: 0.9896 - val_AUC: 0.5747 - val_AUC_PR: 0.2645 - val_loss: 0.2890 - learning_rate: 1.0000e-05
# Epoch 9/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5554 - AUC_PR: 0.2520 - loss: 0.9751 - val_AUC: 0.5792 - val_AUC_PR: 0.2676 - val_loss: 0.2837 - learning_rate: 1.0000e-05
# Epoch 10/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5648 - AUC_PR: 0.2592 - loss: 0.9429 - val_AUC: 0.5838 - val_AUC_PR: 0.2704 - val_loss: 0.2784 - learning_rate: 1.0000e-05
# Epoch 11/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5627 - AUC_PR: 0.2525 - loss: 0.9507 - val_AUC: 0.5880 - val_AUC_PR: 0.2735 - val_loss: 0.2737 - learning_rate: 1.0000e-05
# Epoch 12/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5648 - AUC_PR: 0.2574 - loss: 0.9248 - val_AUC: 0.5924 - val_AUC_PR: 0.2764 - val_loss: 0.2688 - learning_rate: 1.0000e-05
# Epoch 13/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5735 - AUC_PR: 0.2596 - loss: 0.9094 - val_AUC: 0.5962 - val_AUC_PR: 0.2790 - val_loss: 0.2642 - learning_rate: 1.0000e-05
# Epoch 14/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5744 - AUC_PR: 0.2620 - loss: 0.9005 - val_AUC: 0.5999 - val_AUC_PR: 0.2816 - val_loss: 0.2597 - learning_rate: 1.0000e-05
# Epoch 15/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5793 - AUC_PR: 0.2637 - loss: 0.8853 - val_AUC: 0.6041 - val_AUC_PR: 0.2847 - val_loss: 0.2556 - learning_rate: 1.0000e-05
# Epoch 16/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5811 - AUC_PR: 0.2698 - loss: 0.8699 - val_AUC: 0.6076 - val_AUC_PR: 0.2879 - val_loss: 0.2513 - learning_rate: 1.0000e-05
# Epoch 17/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5844 - AUC_PR: 0.2691 - loss: 0.8558 - val_AUC: 0.6116 - val_AUC_PR: 0.2910 - val_loss: 0.2474 - learning_rate: 1.0000e-05
# Epoch 18/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5883 - AUC_PR: 0.2699 - loss: 0.8543 - val_AUC: 0.6152 - val_AUC_PR: 0.2942 - val_loss: 0.2433 - learning_rate: 1.0000e-05
# Epoch 19/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5868 - AUC_PR: 0.2733 - loss: 0.8352 - val_AUC: 0.6184 - val_AUC_PR: 0.2972 - val_loss: 0.2394 - learning_rate: 1.0000e-05
# Epoch 20/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5943 - AUC_PR: 0.2779 - loss: 0.8069 - val_AUC: 0.6217 - val_AUC_PR: 0.3003 - val_loss: 0.2356 - learning_rate: 1.0000e-05
# Epoch 21/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5898 - AUC_PR: 0.2767 - loss: 0.8064 - val_AUC: 0.6243 - val_AUC_PR: 0.3029 - val_loss: 0.2320 - learning_rate: 1.0000e-05
# Epoch 22/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5971 - AUC_PR: 0.2793 - loss: 0.7962 - val_AUC: 0.6277 - val_AUC_PR: 0.3062 - val_loss: 0.2288 - learning_rate: 1.0000e-05
# Epoch 23/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6005 - AUC_PR: 0.2831 - loss: 0.7876 - val_AUC: 0.6307 - val_AUC_PR: 0.3096 - val_loss: 0.2254 - learning_rate: 1.0000e-05
# Epoch 24/2000
# 47/47 - 0s - 2ms/step - AUC: 0.5951 - AUC_PR: 0.2792 - loss: 0.7790 - val_AUC: 0.6334 - val_AUC_PR: 0.3123 - val_loss: 0.2219 - learning_rate: 1.0000e-05
# Epoch 25/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6015 - AUC_PR: 0.2865 - loss: 0.7581 - val_AUC: 0.6356 - val_AUC_PR: 0.3152 - val_loss: 0.2183 - learning_rate: 1.0000e-05
# Epoch 26/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6010 - AUC_PR: 0.2861 - loss: 0.7525 - val_AUC: 0.6384 - val_AUC_PR: 0.3185 - val_loss: 0.2149 - learning_rate: 1.0000e-05
# Epoch 27/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6037 - AUC_PR: 0.2858 - loss: 0.7355 - val_AUC: 0.6411 - val_AUC_PR: 0.3219 - val_loss: 0.2115 - learning_rate: 1.0000e-05
# Epoch 28/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6015 - AUC_PR: 0.2843 - loss: 0.7378 - val_AUC: 0.6429 - val_AUC_PR: 0.3243 - val_loss: 0.2084 - learning_rate: 1.0000e-05
# Epoch 29/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6082 - AUC_PR: 0.2929 - loss: 0.7241 - val_AUC: 0.6448 - val_AUC_PR: 0.3271 - val_loss: 0.2053 - learning_rate: 1.0000e-05
# Epoch 30/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6125 - AUC_PR: 0.2971 - loss: 0.7086 - val_AUC: 0.6477 - val_AUC_PR: 0.3303 - val_loss: 0.2023 - learning_rate: 1.0000e-05
# Epoch 31/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6100 - AUC_PR: 0.2938 - loss: 0.7031 - val_AUC: 0.6498 - val_AUC_PR: 0.3332 - val_loss: 0.1994 - learning_rate: 1.0000e-05
# Epoch 32/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6154 - AUC_PR: 0.2977 - loss: 0.6952 - val_AUC: 0.6519 - val_AUC_PR: 0.3361 - val_loss: 0.1964 - learning_rate: 1.0000e-05
# Epoch 33/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6161 - AUC_PR: 0.3030 - loss: 0.6817 - val_AUC: 0.6533 - val_AUC_PR: 0.3385 - val_loss: 0.1935 - learning_rate: 1.0000e-05
# Epoch 34/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6177 - AUC_PR: 0.3006 - loss: 0.6777 - val_AUC: 0.6556 - val_AUC_PR: 0.3421 - val_loss: 0.1907 - learning_rate: 1.0000e-05
# Epoch 35/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6241 - AUC_PR: 0.3088 - loss: 0.6636 - val_AUC: 0.6573 - val_AUC_PR: 0.3445 - val_loss: 0.1881 - learning_rate: 1.0000e-05
# Epoch 36/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6151 - AUC_PR: 0.3036 - loss: 0.6675 - val_AUC: 0.6587 - val_AUC_PR: 0.3469 - val_loss: 0.1854 - learning_rate: 1.0000e-05
# Epoch 37/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6245 - AUC_PR: 0.3099 - loss: 0.6528 - val_AUC: 0.6604 - val_AUC_PR: 0.3497 - val_loss: 0.1827 - learning_rate: 1.0000e-05
# Epoch 38/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6245 - AUC_PR: 0.3068 - loss: 0.6486 - val_AUC: 0.6622 - val_AUC_PR: 0.3525 - val_loss: 0.1801 - learning_rate: 1.0000e-05
# Epoch 39/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6217 - AUC_PR: 0.3074 - loss: 0.6325 - val_AUC: 0.6633 - val_AUC_PR: 0.3551 - val_loss: 0.1774 - learning_rate: 1.0000e-05
# Epoch 40/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6259 - AUC_PR: 0.3148 - loss: 0.6252 - val_AUC: 0.6646 - val_AUC_PR: 0.3575 - val_loss: 0.1751 - learning_rate: 1.0000e-05
# Epoch 41/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6221 - AUC_PR: 0.3129 - loss: 0.6120 - val_AUC: 0.6658 - val_AUC_PR: 0.3601 - val_loss: 0.1727 - learning_rate: 1.0000e-05
# Epoch 42/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6301 - AUC_PR: 0.3210 - loss: 0.6067 - val_AUC: 0.6671 - val_AUC_PR: 0.3622 - val_loss: 0.1702 - learning_rate: 1.0000e-05
# Epoch 43/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6265 - AUC_PR: 0.3137 - loss: 0.6095 - val_AUC: 0.6681 - val_AUC_PR: 0.3641 - val_loss: 0.1679 - learning_rate: 1.0000e-05
# Epoch 44/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6264 - AUC_PR: 0.3155 - loss: 0.5995 - val_AUC: 0.6693 - val_AUC_PR: 0.3664 - val_loss: 0.1656 - learning_rate: 1.0000e-05
# Epoch 45/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6306 - AUC_PR: 0.3191 - loss: 0.5978 - val_AUC: 0.6707 - val_AUC_PR: 0.3688 - val_loss: 0.1633 - learning_rate: 1.0000e-05
# Epoch 46/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6351 - AUC_PR: 0.3253 - loss: 0.5784 - val_AUC: 0.6714 - val_AUC_PR: 0.3705 - val_loss: 0.1613 - learning_rate: 1.0000e-05
# Epoch 47/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6287 - AUC_PR: 0.3200 - loss: 0.5790 - val_AUC: 0.6726 - val_AUC_PR: 0.3727 - val_loss: 0.1591 - learning_rate: 1.0000e-05
# Epoch 48/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6312 - AUC_PR: 0.3231 - loss: 0.5723 - val_AUC: 0.6731 - val_AUC_PR: 0.3744 - val_loss: 0.1570 - learning_rate: 1.0000e-05
# Epoch 49/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6312 - AUC_PR: 0.3207 - loss: 0.5730 - val_AUC: 0.6739 - val_AUC_PR: 0.3759 - val_loss: 0.1551 - learning_rate: 1.0000e-05
# Epoch 50/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6340 - AUC_PR: 0.3236 - loss: 0.5611 - val_AUC: 0.6752 - val_AUC_PR: 0.3783 - val_loss: 0.1531 - learning_rate: 1.0000e-05
# Epoch 51/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6309 - AUC_PR: 0.3254 - loss: 0.5516 - val_AUC: 0.6760 - val_AUC_PR: 0.3797 - val_loss: 0.1511 - learning_rate: 1.0000e-05
# Epoch 52/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6315 - AUC_PR: 0.3241 - loss: 0.5505 - val_AUC: 0.6769 - val_AUC_PR: 0.3816 - val_loss: 0.1491 - learning_rate: 1.0000e-05
# Epoch 53/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6347 - AUC_PR: 0.3233 - loss: 0.5439 - val_AUC: 0.6778 - val_AUC_PR: 0.3839 - val_loss: 0.1471 - learning_rate: 1.0000e-05
# Epoch 54/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6310 - AUC_PR: 0.3227 - loss: 0.5318 - val_AUC: 0.6782 - val_AUC_PR: 0.3849 - val_loss: 0.1452 - learning_rate: 1.0000e-05
# Epoch 55/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6298 - AUC_PR: 0.3237 - loss: 0.5348 - val_AUC: 0.6791 - val_AUC_PR: 0.3869 - val_loss: 0.1435 - learning_rate: 1.0000e-05
# Epoch 56/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6318 - AUC_PR: 0.3281 - loss: 0.5224 - val_AUC: 0.6798 - val_AUC_PR: 0.3886 - val_loss: 0.1418 - learning_rate: 1.0000e-05
# Epoch 57/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6358 - AUC_PR: 0.3329 - loss: 0.5160 - val_AUC: 0.6805 - val_AUC_PR: 0.3913 - val_loss: 0.1400 - learning_rate: 1.0000e-05
# Epoch 58/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6348 - AUC_PR: 0.3295 - loss: 0.5152 - val_AUC: 0.6810 - val_AUC_PR: 0.3922 - val_loss: 0.1382 - learning_rate: 1.0000e-05
# Epoch 59/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6307 - AUC_PR: 0.3274 - loss: 0.5113 - val_AUC: 0.6813 - val_AUC_PR: 0.3936 - val_loss: 0.1365 - learning_rate: 1.0000e-05
# Epoch 60/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6341 - AUC_PR: 0.3345 - loss: 0.5016 - val_AUC: 0.6821 - val_AUC_PR: 0.3962 - val_loss: 0.1348 - learning_rate: 1.0000e-05
# Epoch 61/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6369 - AUC_PR: 0.3340 - loss: 0.5021 - val_AUC: 0.6828 - val_AUC_PR: 0.3978 - val_loss: 0.1331 - learning_rate: 1.0000e-05
# Epoch 62/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6372 - AUC_PR: 0.3342 - loss: 0.4973 - val_AUC: 0.6836 - val_AUC_PR: 0.3993 - val_loss: 0.1315 - learning_rate: 1.0000e-05
# Epoch 63/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6357 - AUC_PR: 0.3292 - loss: 0.4868 - val_AUC: 0.6840 - val_AUC_PR: 0.4003 - val_loss: 0.1297 - learning_rate: 1.0000e-05
# Epoch 64/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6390 - AUC_PR: 0.3349 - loss: 0.4782 - val_AUC: 0.6847 - val_AUC_PR: 0.4020 - val_loss: 0.1281 - learning_rate: 1.0000e-05
# Epoch 65/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6361 - AUC_PR: 0.3328 - loss: 0.4766 - val_AUC: 0.6856 - val_AUC_PR: 0.4033 - val_loss: 0.1266 - learning_rate: 1.0000e-05
# Epoch 66/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6409 - AUC_PR: 0.3378 - loss: 0.4733 - val_AUC: 0.6857 - val_AUC_PR: 0.4047 - val_loss: 0.1251 - learning_rate: 1.0000e-05
# Epoch 67/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6363 - AUC_PR: 0.3348 - loss: 0.4689 - val_AUC: 0.6863 - val_AUC_PR: 0.4065 - val_loss: 0.1237 - learning_rate: 1.0000e-05
# Epoch 68/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6413 - AUC_PR: 0.3374 - loss: 0.4655 - val_AUC: 0.6864 - val_AUC_PR: 0.4072 - val_loss: 0.1223 - learning_rate: 1.0000e-05
# Epoch 69/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6340 - AUC_PR: 0.3334 - loss: 0.4637 - val_AUC: 0.6871 - val_AUC_PR: 0.4083 - val_loss: 0.1209 - learning_rate: 1.0000e-05
# Epoch 70/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6349 - AUC_PR: 0.3370 - loss: 0.4571 - val_AUC: 0.6879 - val_AUC_PR: 0.4097 - val_loss: 0.1194 - learning_rate: 1.0000e-05
# Epoch 71/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6406 - AUC_PR: 0.3419 - loss: 0.4453 - val_AUC: 0.6881 - val_AUC_PR: 0.4110 - val_loss: 0.1180 - learning_rate: 1.0000e-05
# Epoch 72/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6407 - AUC_PR: 0.3431 - loss: 0.4467 - val_AUC: 0.6885 - val_AUC_PR: 0.4118 - val_loss: 0.1167 - learning_rate: 1.0000e-05
# Epoch 73/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6372 - AUC_PR: 0.3343 - loss: 0.4429 - val_AUC: 0.6888 - val_AUC_PR: 0.4133 - val_loss: 0.1153 - learning_rate: 1.0000e-05
# Epoch 74/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6374 - AUC_PR: 0.3377 - loss: 0.4391 - val_AUC: 0.6896 - val_AUC_PR: 0.4148 - val_loss: 0.1140 - learning_rate: 1.0000e-05
# Epoch 75/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6400 - AUC_PR: 0.3415 - loss: 0.4358 - val_AUC: 0.6898 - val_AUC_PR: 0.4159 - val_loss: 0.1126 - learning_rate: 1.0000e-05
# Epoch 76/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6407 - AUC_PR: 0.3442 - loss: 0.4234 - val_AUC: 0.6900 - val_AUC_PR: 0.4168 - val_loss: 0.1113 - learning_rate: 1.0000e-05
# Epoch 77/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6387 - AUC_PR: 0.3354 - loss: 0.4271 - val_AUC: 0.6906 - val_AUC_PR: 0.4176 - val_loss: 0.1100 - learning_rate: 1.0000e-05
# Epoch 78/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6419 - AUC_PR: 0.3427 - loss: 0.4214 - val_AUC: 0.6907 - val_AUC_PR: 0.4188 - val_loss: 0.1088 - learning_rate: 1.0000e-05
# Epoch 79/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6391 - AUC_PR: 0.3383 - loss: 0.4208 - val_AUC: 0.6913 - val_AUC_PR: 0.4200 - val_loss: 0.1077 - learning_rate: 1.0000e-05
# Epoch 80/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6431 - AUC_PR: 0.3477 - loss: 0.4086 - val_AUC: 0.6916 - val_AUC_PR: 0.4215 - val_loss: 0.1065 - learning_rate: 1.0000e-05
# Epoch 81/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6396 - AUC_PR: 0.3395 - loss: 0.4112 - val_AUC: 0.6920 - val_AUC_PR: 0.4222 - val_loss: 0.1053 - learning_rate: 1.0000e-05
# Epoch 82/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6419 - AUC_PR: 0.3438 - loss: 0.4065 - val_AUC: 0.6927 - val_AUC_PR: 0.4237 - val_loss: 0.1042 - learning_rate: 1.0000e-05
# Epoch 83/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6368 - AUC_PR: 0.3407 - loss: 0.4033 - val_AUC: 0.6930 - val_AUC_PR: 0.4239 - val_loss: 0.1031 - learning_rate: 1.0000e-05
# Epoch 84/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6424 - AUC_PR: 0.3455 - loss: 0.3946 - val_AUC: 0.6936 - val_AUC_PR: 0.4256 - val_loss: 0.1020 - learning_rate: 1.0000e-05
# Epoch 85/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6465 - AUC_PR: 0.3494 - loss: 0.3913 - val_AUC: 0.6934 - val_AUC_PR: 0.4256 - val_loss: 0.1009 - learning_rate: 1.0000e-05
# Epoch 86/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6355 - AUC_PR: 0.3351 - loss: 0.3947 - val_AUC: 0.6939 - val_AUC_PR: 0.4264 - val_loss: 0.0998 - learning_rate: 1.0000e-05
# Epoch 87/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6419 - AUC_PR: 0.3387 - loss: 0.3912 - val_AUC: 0.6945 - val_AUC_PR: 0.4277 - val_loss: 0.0988 - learning_rate: 1.0000e-05
# Epoch 88/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6381 - AUC_PR: 0.3397 - loss: 0.3896 - val_AUC: 0.6947 - val_AUC_PR: 0.4285 - val_loss: 0.0978 - learning_rate: 1.0000e-05
# Epoch 89/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6370 - AUC_PR: 0.3428 - loss: 0.3862 - val_AUC: 0.6949 - val_AUC_PR: 0.4289 - val_loss: 0.0966 - learning_rate: 1.0000e-05
# Epoch 90/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6425 - AUC_PR: 0.3460 - loss: 0.3742 - val_AUC: 0.6950 - val_AUC_PR: 0.4295 - val_loss: 0.0957 - learning_rate: 1.0000e-05
# Epoch 91/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6398 - AUC_PR: 0.3415 - loss: 0.3755 - val_AUC: 0.6959 - val_AUC_PR: 0.4313 - val_loss: 0.0948 - learning_rate: 1.0000e-05
# Epoch 92/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6377 - AUC_PR: 0.3471 - loss: 0.3705 - val_AUC: 0.6967 - val_AUC_PR: 0.4324 - val_loss: 0.0938 - learning_rate: 1.0000e-05
# Epoch 93/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6369 - AUC_PR: 0.3406 - loss: 0.3705 - val_AUC: 0.6966 - val_AUC_PR: 0.4332 - val_loss: 0.0929 - learning_rate: 1.0000e-05
# Epoch 94/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6461 - AUC_PR: 0.3456 - loss: 0.3696 - val_AUC: 0.6967 - val_AUC_PR: 0.4339 - val_loss: 0.0920 - learning_rate: 1.0000e-05
# Epoch 95/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6407 - AUC_PR: 0.3468 - loss: 0.3617 - val_AUC: 0.6970 - val_AUC_PR: 0.4347 - val_loss: 0.0912 - learning_rate: 1.0000e-05
# Epoch 96/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6409 - AUC_PR: 0.3450 - loss: 0.3593 - val_AUC: 0.6968 - val_AUC_PR: 0.4354 - val_loss: 0.0903 - learning_rate: 1.0000e-05
# Epoch 97/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6373 - AUC_PR: 0.3408 - loss: 0.3588 - val_AUC: 0.6977 - val_AUC_PR: 0.4359 - val_loss: 0.0895 - learning_rate: 1.0000e-05
# Epoch 98/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6403 - AUC_PR: 0.3454 - loss: 0.3519 - val_AUC: 0.6982 - val_AUC_PR: 0.4372 - val_loss: 0.0886 - learning_rate: 1.0000e-05
# Epoch 99/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6418 - AUC_PR: 0.3422 - loss: 0.3525 - val_AUC: 0.6988 - val_AUC_PR: 0.4382 - val_loss: 0.0878 - learning_rate: 1.0000e-05
# Epoch 100/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6419 - AUC_PR: 0.3420 - loss: 0.3497 - val_AUC: 0.6991 - val_AUC_PR: 0.4385 - val_loss: 0.0870 - learning_rate: 1.0000e-05
# Epoch 101/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6414 - AUC_PR: 0.3427 - loss: 0.3472 - val_AUC: 0.6999 - val_AUC_PR: 0.4398 - val_loss: 0.0862 - learning_rate: 1.0000e-05
# Epoch 102/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6399 - AUC_PR: 0.3431 - loss: 0.3444 - val_AUC: 0.7001 - val_AUC_PR: 0.4402 - val_loss: 0.0854 - learning_rate: 1.0000e-05
# Epoch 103/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6480 - AUC_PR: 0.3465 - loss: 0.3408 - val_AUC: 0.7009 - val_AUC_PR: 0.4413 - val_loss: 0.0847 - learning_rate: 1.0000e-05
# Epoch 104/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6427 - AUC_PR: 0.3444 - loss: 0.3382 - val_AUC: 0.7013 - val_AUC_PR: 0.4419 - val_loss: 0.0839 - learning_rate: 1.0000e-05
# Epoch 105/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6389 - AUC_PR: 0.3370 - loss: 0.3389 - val_AUC: 0.7020 - val_AUC_PR: 0.4428 - val_loss: 0.0831 - learning_rate: 1.0000e-05
# Epoch 106/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6398 - AUC_PR: 0.3419 - loss: 0.3344 - val_AUC: 0.7021 - val_AUC_PR: 0.4435 - val_loss: 0.0824 - learning_rate: 1.0000e-05
# Epoch 107/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6416 - AUC_PR: 0.3398 - loss: 0.3320 - val_AUC: 0.7022 - val_AUC_PR: 0.4440 - val_loss: 0.0818 - learning_rate: 1.0000e-05
# Epoch 108/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6432 - AUC_PR: 0.3478 - loss: 0.3300 - val_AUC: 0.7031 - val_AUC_PR: 0.4450 - val_loss: 0.0811 - learning_rate: 1.0000e-05
# Epoch 109/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6420 - AUC_PR: 0.3424 - loss: 0.3267 - val_AUC: 0.7033 - val_AUC_PR: 0.4451 - val_loss: 0.0804 - learning_rate: 1.0000e-05
# Epoch 110/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6476 - AUC_PR: 0.3483 - loss: 0.3192 - val_AUC: 0.7031 - val_AUC_PR: 0.4458 - val_loss: 0.0798 - learning_rate: 1.0000e-05
# Epoch 111/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6372 - AUC_PR: 0.3383 - loss: 0.3263 - val_AUC: 0.7036 - val_AUC_PR: 0.4459 - val_loss: 0.0790 - learning_rate: 1.0000e-05
# Epoch 112/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6376 - AUC_PR: 0.3424 - loss: 0.3188 - val_AUC: 0.7039 - val_AUC_PR: 0.4460 - val_loss: 0.0784 - learning_rate: 1.0000e-05
# Epoch 113/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6445 - AUC_PR: 0.3490 - loss: 0.3181 - val_AUC: 0.7039 - val_AUC_PR: 0.4470 - val_loss: 0.0778 - learning_rate: 1.0000e-05
# Epoch 114/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6392 - AUC_PR: 0.3412 - loss: 0.3152 - val_AUC: 0.7048 - val_AUC_PR: 0.4477 - val_loss: 0.0772 - learning_rate: 1.0000e-05
# Epoch 115/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6438 - AUC_PR: 0.3466 - loss: 0.3131 - val_AUC: 0.7055 - val_AUC_PR: 0.4481 - val_loss: 0.0767 - learning_rate: 1.0000e-05
# Epoch 116/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6475 - AUC_PR: 0.3506 - loss: 0.3090 - val_AUC: 0.7051 - val_AUC_PR: 0.4483 - val_loss: 0.0761 - learning_rate: 1.0000e-05
# Epoch 117/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6460 - AUC_PR: 0.3492 - loss: 0.3081 - val_AUC: 0.7058 - val_AUC_PR: 0.4485 - val_loss: 0.0755 - learning_rate: 1.0000e-05
# Epoch 118/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6430 - AUC_PR: 0.3406 - loss: 0.3075 - val_AUC: 0.7063 - val_AUC_PR: 0.4489 - val_loss: 0.0749 - learning_rate: 1.0000e-05
# Epoch 119/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6455 - AUC_PR: 0.3467 - loss: 0.3020 - val_AUC: 0.7066 - val_AUC_PR: 0.4497 - val_loss: 0.0743 - learning_rate: 1.0000e-05
# Epoch 120/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6446 - AUC_PR: 0.3455 - loss: 0.3023 - val_AUC: 0.7078 - val_AUC_PR: 0.4500 - val_loss: 0.0738 - learning_rate: 1.0000e-05
# Epoch 121/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6473 - AUC_PR: 0.3443 - loss: 0.3022 - val_AUC: 0.7084 - val_AUC_PR: 0.4510 - val_loss: 0.0732 - learning_rate: 1.0000e-05
# Epoch 122/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6462 - AUC_PR: 0.3516 - loss: 0.2947 - val_AUC: 0.7086 - val_AUC_PR: 0.4515 - val_loss: 0.0727 - learning_rate: 1.0000e-05
# Epoch 123/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6428 - AUC_PR: 0.3474 - loss: 0.2948 - val_AUC: 0.7092 - val_AUC_PR: 0.4524 - val_loss: 0.0722 - learning_rate: 1.0000e-05
# Epoch 124/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6481 - AUC_PR: 0.3505 - loss: 0.2945 - val_AUC: 0.7095 - val_AUC_PR: 0.4525 - val_loss: 0.0718 - learning_rate: 1.0000e-05
# Epoch 125/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6443 - AUC_PR: 0.3470 - loss: 0.2938 - val_AUC: 0.7098 - val_AUC_PR: 0.4537 - val_loss: 0.0713 - learning_rate: 1.0000e-05
# Epoch 126/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6443 - AUC_PR: 0.3479 - loss: 0.2904 - val_AUC: 0.7101 - val_AUC_PR: 0.4532 - val_loss: 0.0708 - learning_rate: 1.0000e-05
# Epoch 127/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6492 - AUC_PR: 0.3492 - loss: 0.2868 - val_AUC: 0.7109 - val_AUC_PR: 0.4539 - val_loss: 0.0704 - learning_rate: 1.0000e-05
# Epoch 128/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6489 - AUC_PR: 0.3462 - loss: 0.2847 - val_AUC: 0.7113 - val_AUC_PR: 0.4543 - val_loss: 0.0699 - learning_rate: 1.0000e-05
# Epoch 129/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6472 - AUC_PR: 0.3499 - loss: 0.2858 - val_AUC: 0.7120 - val_AUC_PR: 0.4549 - val_loss: 0.0695 - learning_rate: 1.0000e-05
# Epoch 130/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6483 - AUC_PR: 0.3551 - loss: 0.2807 - val_AUC: 0.7126 - val_AUC_PR: 0.4552 - val_loss: 0.0691 - learning_rate: 1.0000e-05
# Epoch 131/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6488 - AUC_PR: 0.3453 - loss: 0.2840 - val_AUC: 0.7130 - val_AUC_PR: 0.4559 - val_loss: 0.0687 - learning_rate: 1.0000e-05
# Epoch 132/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6488 - AUC_PR: 0.3535 - loss: 0.2807 - val_AUC: 0.7130 - val_AUC_PR: 0.4558 - val_loss: 0.0682 - learning_rate: 1.0000e-05
# Epoch 133/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6465 - AUC_PR: 0.3498 - loss: 0.2810 - val_AUC: 0.7137 - val_AUC_PR: 0.4560 - val_loss: 0.0679 - learning_rate: 1.0000e-05
# Epoch 134/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6480 - AUC_PR: 0.3441 - loss: 0.2799 - val_AUC: 0.7142 - val_AUC_PR: 0.4571 - val_loss: 0.0675 - learning_rate: 1.0000e-05
# Epoch 135/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6448 - AUC_PR: 0.3451 - loss: 0.2787 - val_AUC: 0.7144 - val_AUC_PR: 0.4571 - val_loss: 0.0671 - learning_rate: 1.0000e-05
# Epoch 136/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6529 - AUC_PR: 0.3551 - loss: 0.2742 - val_AUC: 0.7149 - val_AUC_PR: 0.4574 - val_loss: 0.0667 - learning_rate: 1.0000e-05
# Epoch 137/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6575 - AUC_PR: 0.3570 - loss: 0.2701 - val_AUC: 0.7158 - val_AUC_PR: 0.4584 - val_loss: 0.0663 - learning_rate: 1.0000e-05
# Epoch 138/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6521 - AUC_PR: 0.3527 - loss: 0.2699 - val_AUC: 0.7159 - val_AUC_PR: 0.4580 - val_loss: 0.0660 - learning_rate: 1.0000e-05
# Epoch 139/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6476 - AUC_PR: 0.3531 - loss: 0.2701 - val_AUC: 0.7162 - val_AUC_PR: 0.4584 - val_loss: 0.0656 - learning_rate: 1.0000e-05
# Epoch 140/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6527 - AUC_PR: 0.3573 - loss: 0.2668 - val_AUC: 0.7165 - val_AUC_PR: 0.4593 - val_loss: 0.0653 - learning_rate: 1.0000e-05
# Epoch 141/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6520 - AUC_PR: 0.3517 - loss: 0.2646 - val_AUC: 0.7171 - val_AUC_PR: 0.4596 - val_loss: 0.0650 - learning_rate: 1.0000e-05
# Epoch 142/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6543 - AUC_PR: 0.3581 - loss: 0.2626 - val_AUC: 0.7178 - val_AUC_PR: 0.4599 - val_loss: 0.0646 - learning_rate: 1.0000e-05
# Epoch 143/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6482 - AUC_PR: 0.3496 - loss: 0.2660 - val_AUC: 0.7185 - val_AUC_PR: 0.4607 - val_loss: 0.0643 - learning_rate: 1.0000e-05
# Epoch 144/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6506 - AUC_PR: 0.3533 - loss: 0.2638 - val_AUC: 0.7192 - val_AUC_PR: 0.4614 - val_loss: 0.0640 - learning_rate: 1.0000e-05
# Epoch 145/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6445 - AUC_PR: 0.3443 - loss: 0.2671 - val_AUC: 0.7191 - val_AUC_PR: 0.4611 - val_loss: 0.0637 - learning_rate: 1.0000e-05
# Epoch 146/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6499 - AUC_PR: 0.3548 - loss: 0.2609 - val_AUC: 0.7206 - val_AUC_PR: 0.4621 - val_loss: 0.0634 - learning_rate: 1.0000e-05
# Epoch 147/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6513 - AUC_PR: 0.3532 - loss: 0.2599 - val_AUC: 0.7208 - val_AUC_PR: 0.4625 - val_loss: 0.0631 - learning_rate: 1.0000e-05
# Epoch 148/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6519 - AUC_PR: 0.3556 - loss: 0.2592 - val_AUC: 0.7215 - val_AUC_PR: 0.4630 - val_loss: 0.0629 - learning_rate: 1.0000e-05
# Epoch 149/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6546 - AUC_PR: 0.3489 - loss: 0.2571 - val_AUC: 0.7215 - val_AUC_PR: 0.4627 - val_loss: 0.0626 - learning_rate: 1.0000e-05
# Epoch 150/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6515 - AUC_PR: 0.3544 - loss: 0.2579 - val_AUC: 0.7217 - val_AUC_PR: 0.4633 - val_loss: 0.0624 - learning_rate: 1.0000e-05
# Epoch 151/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6565 - AUC_PR: 0.3582 - loss: 0.2531 - val_AUC: 0.7225 - val_AUC_PR: 0.4640 - val_loss: 0.0621 - learning_rate: 1.0000e-05
# Epoch 152/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6490 - AUC_PR: 0.3491 - loss: 0.2561 - val_AUC: 0.7229 - val_AUC_PR: 0.4645 - val_loss: 0.0618 - learning_rate: 1.0000e-05
# Epoch 153/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6545 - AUC_PR: 0.3562 - loss: 0.2524 - val_AUC: 0.7227 - val_AUC_PR: 0.4650 - val_loss: 0.0616 - learning_rate: 1.0000e-05
# Epoch 154/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6556 - AUC_PR: 0.3579 - loss: 0.2507 - val_AUC: 0.7233 - val_AUC_PR: 0.4654 - val_loss: 0.0614 - learning_rate: 1.0000e-05
# Epoch 155/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6563 - AUC_PR: 0.3602 - loss: 0.2486 - val_AUC: 0.7242 - val_AUC_PR: 0.4656 - val_loss: 0.0611 - learning_rate: 1.0000e-05
# Epoch 156/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6576 - AUC_PR: 0.3615 - loss: 0.2451 - val_AUC: 0.7249 - val_AUC_PR: 0.4659 - val_loss: 0.0609 - learning_rate: 1.0000e-05
# Epoch 157/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6581 - AUC_PR: 0.3607 - loss: 0.2477 - val_AUC: 0.7250 - val_AUC_PR: 0.4659 - val_loss: 0.0606 - learning_rate: 1.0000e-05
# Epoch 158/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6492 - AUC_PR: 0.3512 - loss: 0.2510 - val_AUC: 0.7253 - val_AUC_PR: 0.4670 - val_loss: 0.0604 - learning_rate: 1.0000e-05
# Epoch 159/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6586 - AUC_PR: 0.3581 - loss: 0.2448 - val_AUC: 0.7258 - val_AUC_PR: 0.4671 - val_loss: 0.0602 - learning_rate: 1.0000e-05
# Epoch 160/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6543 - AUC_PR: 0.3616 - loss: 0.2454 - val_AUC: 0.7266 - val_AUC_PR: 0.4674 - val_loss: 0.0600 - learning_rate: 1.0000e-05
# Epoch 161/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6507 - AUC_PR: 0.3529 - loss: 0.2438 - val_AUC: 0.7272 - val_AUC_PR: 0.4682 - val_loss: 0.0598 - learning_rate: 1.0000e-05
# Epoch 162/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6493 - AUC_PR: 0.3522 - loss: 0.2457 - val_AUC: 0.7279 - val_AUC_PR: 0.4688 - val_loss: 0.0596 - learning_rate: 1.0000e-05
# Epoch 163/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6549 - AUC_PR: 0.3568 - loss: 0.2436 - val_AUC: 0.7277 - val_AUC_PR: 0.4684 - val_loss: 0.0594 - learning_rate: 1.0000e-05
# Epoch 164/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6538 - AUC_PR: 0.3504 - loss: 0.2441 - val_AUC: 0.7283 - val_AUC_PR: 0.4690 - val_loss: 0.0592 - learning_rate: 1.0000e-05
# Epoch 165/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6607 - AUC_PR: 0.3580 - loss: 0.2415 - val_AUC: 0.7289 - val_AUC_PR: 0.4702 - val_loss: 0.0590 - learning_rate: 1.0000e-05
# Epoch 166/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6530 - AUC_PR: 0.3516 - loss: 0.2386 - val_AUC: 0.7297 - val_AUC_PR: 0.4701 - val_loss: 0.0589 - learning_rate: 1.0000e-05
# Epoch 167/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6603 - AUC_PR: 0.3628 - loss: 0.2393 - val_AUC: 0.7298 - val_AUC_PR: 0.4704 - val_loss: 0.0587 - learning_rate: 1.0000e-05
# Epoch 168/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6607 - AUC_PR: 0.3553 - loss: 0.2377 - val_AUC: 0.7307 - val_AUC_PR: 0.4707 - val_loss: 0.0585 - learning_rate: 1.0000e-05
# Epoch 169/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6584 - AUC_PR: 0.3598 - loss: 0.2372 - val_AUC: 0.7312 - val_AUC_PR: 0.4709 - val_loss: 0.0584 - learning_rate: 1.0000e-05
# Epoch 170/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6626 - AUC_PR: 0.3612 - loss: 0.2350 - val_AUC: 0.7318 - val_AUC_PR: 0.4722 - val_loss: 0.0582 - learning_rate: 1.0000e-05
# Epoch 171/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6680 - AUC_PR: 0.3626 - loss: 0.2349 - val_AUC: 0.7328 - val_AUC_PR: 0.4725 - val_loss: 0.0581 - learning_rate: 1.0000e-05
# Epoch 172/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6683 - AUC_PR: 0.3724 - loss: 0.2316 - val_AUC: 0.7324 - val_AUC_PR: 0.4730 - val_loss: 0.0579 - learning_rate: 1.0000e-05
# Epoch 173/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6609 - AUC_PR: 0.3585 - loss: 0.2339 - val_AUC: 0.7324 - val_AUC_PR: 0.4727 - val_loss: 0.0578 - learning_rate: 1.0000e-05
# Epoch 174/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6575 - AUC_PR: 0.3518 - loss: 0.2364 - val_AUC: 0.7332 - val_AUC_PR: 0.4732 - val_loss: 0.0577 - learning_rate: 1.0000e-05
# Epoch 175/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6624 - AUC_PR: 0.3631 - loss: 0.2329 - val_AUC: 0.7336 - val_AUC_PR: 0.4738 - val_loss: 0.0575 - learning_rate: 1.0000e-05
# Epoch 176/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6568 - AUC_PR: 0.3570 - loss: 0.2325 - val_AUC: 0.7341 - val_AUC_PR: 0.4745 - val_loss: 0.0574 - learning_rate: 1.0000e-05
# Epoch 177/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6635 - AUC_PR: 0.3674 - loss: 0.2303 - val_AUC: 0.7345 - val_AUC_PR: 0.4750 - val_loss: 0.0573 - learning_rate: 1.0000e-05
# Epoch 178/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6555 - AUC_PR: 0.3518 - loss: 0.2343 - val_AUC: 0.7348 - val_AUC_PR: 0.4758 - val_loss: 0.0572 - learning_rate: 1.0000e-05
# Epoch 179/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6622 - AUC_PR: 0.3601 - loss: 0.2286 - val_AUC: 0.7354 - val_AUC_PR: 0.4762 - val_loss: 0.0571 - learning_rate: 1.0000e-05
# Epoch 180/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6671 - AUC_PR: 0.3638 - loss: 0.2294 - val_AUC: 0.7355 - val_AUC_PR: 0.4758 - val_loss: 0.0570 - learning_rate: 1.0000e-05
# Epoch 181/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6689 - AUC_PR: 0.3668 - loss: 0.2250 - val_AUC: 0.7360 - val_AUC_PR: 0.4764 - val_loss: 0.0568 - learning_rate: 1.0000e-05
# Epoch 182/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6628 - AUC_PR: 0.3620 - loss: 0.2288 - val_AUC: 0.7365 - val_AUC_PR: 0.4764 - val_loss: 0.0567 - learning_rate: 1.0000e-05
# Epoch 183/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6616 - AUC_PR: 0.3651 - loss: 0.2280 - val_AUC: 0.7374 - val_AUC_PR: 0.4773 - val_loss: 0.0566 - learning_rate: 1.0000e-05
# Epoch 184/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6631 - AUC_PR: 0.3644 - loss: 0.2284 - val_AUC: 0.7378 - val_AUC_PR: 0.4778 - val_loss: 0.0565 - learning_rate: 1.0000e-05
# Epoch 185/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6644 - AUC_PR: 0.3583 - loss: 0.2284 - val_AUC: 0.7383 - val_AUC_PR: 0.4782 - val_loss: 0.0564 - learning_rate: 1.0000e-05
# Epoch 186/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6677 - AUC_PR: 0.3692 - loss: 0.2240 - val_AUC: 0.7386 - val_AUC_PR: 0.4782 - val_loss: 0.0563 - learning_rate: 1.0000e-05
# Epoch 187/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6588 - AUC_PR: 0.3572 - loss: 0.2275 - val_AUC: 0.7393 - val_AUC_PR: 0.4791 - val_loss: 0.0562 - learning_rate: 1.0000e-05
# Epoch 188/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6682 - AUC_PR: 0.3689 - loss: 0.2218 - val_AUC: 0.7399 - val_AUC_PR: 0.4795 - val_loss: 0.0561 - learning_rate: 1.0000e-05
# Epoch 189/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6697 - AUC_PR: 0.3714 - loss: 0.2227 - val_AUC: 0.7405 - val_AUC_PR: 0.4802 - val_loss: 0.0561 - learning_rate: 1.0000e-05
# Epoch 190/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6636 - AUC_PR: 0.3628 - loss: 0.2247 - val_AUC: 0.7406 - val_AUC_PR: 0.4806 - val_loss: 0.0560 - learning_rate: 1.0000e-05
# Epoch 191/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6724 - AUC_PR: 0.3642 - loss: 0.2208 - val_AUC: 0.7412 - val_AUC_PR: 0.4805 - val_loss: 0.0559 - learning_rate: 1.0000e-05
# Epoch 192/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6676 - AUC_PR: 0.3715 - loss: 0.2210 - val_AUC: 0.7416 - val_AUC_PR: 0.4809 - val_loss: 0.0558 - learning_rate: 1.0000e-05
# Epoch 193/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6719 - AUC_PR: 0.3730 - loss: 0.2208 - val_AUC: 0.7420 - val_AUC_PR: 0.4816 - val_loss: 0.0558 - learning_rate: 1.0000e-05
# Epoch 194/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6728 - AUC_PR: 0.3734 - loss: 0.2203 - val_AUC: 0.7424 - val_AUC_PR: 0.4821 - val_loss: 0.0557 - learning_rate: 1.0000e-05
# Epoch 195/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6721 - AUC_PR: 0.3697 - loss: 0.2206 - val_AUC: 0.7428 - val_AUC_PR: 0.4823 - val_loss: 0.0556 - learning_rate: 1.0000e-05
# Epoch 196/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6673 - AUC_PR: 0.3669 - loss: 0.2228 - val_AUC: 0.7434 - val_AUC_PR: 0.4829 - val_loss: 0.0555 - learning_rate: 1.0000e-05
# Epoch 197/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6706 - AUC_PR: 0.3708 - loss: 0.2199 - val_AUC: 0.7440 - val_AUC_PR: 0.4833 - val_loss: 0.0555 - learning_rate: 1.0000e-05
# Epoch 198/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6680 - AUC_PR: 0.3723 - loss: 0.2181 - val_AUC: 0.7440 - val_AUC_PR: 0.4832 - val_loss: 0.0554 - learning_rate: 1.0000e-05
# Epoch 199/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6693 - AUC_PR: 0.3658 - loss: 0.2197 - val_AUC: 0.7441 - val_AUC_PR: 0.4838 - val_loss: 0.0554 - learning_rate: 1.0000e-05
# Epoch 200/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6754 - AUC_PR: 0.3709 - loss: 0.2174 - val_AUC: 0.7443 - val_AUC_PR: 0.4836 - val_loss: 0.0553 - learning_rate: 1.0000e-05
# Epoch 201/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6766 - AUC_PR: 0.3776 - loss: 0.2149 - val_AUC: 0.7453 - val_AUC_PR: 0.4841 - val_loss: 0.0552 - learning_rate: 1.0000e-05
# Epoch 202/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6704 - AUC_PR: 0.3684 - loss: 0.2202 - val_AUC: 0.7454 - val_AUC_PR: 0.4844 - val_loss: 0.0552 - learning_rate: 1.0000e-05
# Epoch 203/2000
# 47/47 - 0s - 3ms/step - AUC: 0.6730 - AUC_PR: 0.3714 - loss: 0.2178 - val_AUC: 0.7454 - val_AUC_PR: 0.4842 - val_loss: 0.0551 - learning_rate: 1.0000e-05
# Epoch 204/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6731 - AUC_PR: 0.3713 - loss: 0.2172 - val_AUC: 0.7461 - val_AUC_PR: 0.4843 - val_loss: 0.0551 - learning_rate: 1.0000e-05
# Epoch 205/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6757 - AUC_PR: 0.3809 - loss: 0.2165 - val_AUC: 0.7464 - val_AUC_PR: 0.4850 - val_loss: 0.0550 - learning_rate: 1.0000e-05
# Epoch 206/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6770 - AUC_PR: 0.3725 - loss: 0.2157 - val_AUC: 0.7467 - val_AUC_PR: 0.4852 - val_loss: 0.0550 - learning_rate: 1.0000e-05
# Epoch 207/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6741 - AUC_PR: 0.3739 - loss: 0.2174 - val_AUC: 0.7466 - val_AUC_PR: 0.4859 - val_loss: 0.0550 - learning_rate: 1.0000e-05
# Epoch 208/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6726 - AUC_PR: 0.3692 - loss: 0.2159 - val_AUC: 0.7469 - val_AUC_PR: 0.4861 - val_loss: 0.0549 - learning_rate: 1.0000e-05
# Epoch 209/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6746 - AUC_PR: 0.3713 - loss: 0.2152 - val_AUC: 0.7478 - val_AUC_PR: 0.4865 - val_loss: 0.0549 - learning_rate: 1.0000e-05
# Epoch 210/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6708 - AUC_PR: 0.3648 - loss: 0.2168 - val_AUC: 0.7484 - val_AUC_PR: 0.4871 - val_loss: 0.0548 - learning_rate: 1.0000e-05
# Epoch 211/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6756 - AUC_PR: 0.3716 - loss: 0.2143 - val_AUC: 0.7484 - val_AUC_PR: 0.4870 - val_loss: 0.0548 - learning_rate: 1.0000e-05
# Epoch 212/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6772 - AUC_PR: 0.3703 - loss: 0.2146 - val_AUC: 0.7485 - val_AUC_PR: 0.4871 - val_loss: 0.0548 - learning_rate: 1.0000e-05
# Epoch 213/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6767 - AUC_PR: 0.3823 - loss: 0.2127 - val_AUC: 0.7493 - val_AUC_PR: 0.4877 - val_loss: 0.0547 - learning_rate: 1.0000e-05
# Epoch 214/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6736 - AUC_PR: 0.3697 - loss: 0.2150 - val_AUC: 0.7498 - val_AUC_PR: 0.4882 - val_loss: 0.0547 - learning_rate: 1.0000e-05
# Epoch 215/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6851 - AUC_PR: 0.3836 - loss: 0.2081 - val_AUC: 0.7499 - val_AUC_PR: 0.4885 - val_loss: 0.0547 - learning_rate: 1.0000e-05
# Epoch 216/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6796 - AUC_PR: 0.3763 - loss: 0.2137 - val_AUC: 0.7505 - val_AUC_PR: 0.4887 - val_loss: 0.0546 - learning_rate: 1.0000e-05
# Epoch 217/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6809 - AUC_PR: 0.3747 - loss: 0.2112 - val_AUC: 0.7507 - val_AUC_PR: 0.4889 - val_loss: 0.0546 - learning_rate: 1.0000e-05
# Epoch 218/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6794 - AUC_PR: 0.3787 - loss: 0.2105 - val_AUC: 0.7512 - val_AUC_PR: 0.4897 - val_loss: 0.0546 - learning_rate: 1.0000e-05
# Epoch 219/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6826 - AUC_PR: 0.3782 - loss: 0.2105 - val_AUC: 0.7517 - val_AUC_PR: 0.4898 - val_loss: 0.0545 - learning_rate: 1.0000e-05
# Epoch 220/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6788 - AUC_PR: 0.3780 - loss: 0.2118 - val_AUC: 0.7519 - val_AUC_PR: 0.4905 - val_loss: 0.0545 - learning_rate: 1.0000e-05
# Epoch 221/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6863 - AUC_PR: 0.3819 - loss: 0.2085 - val_AUC: 0.7519 - val_AUC_PR: 0.4903 - val_loss: 0.0545 - learning_rate: 1.0000e-05
# Epoch 222/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6809 - AUC_PR: 0.3774 - loss: 0.2096 - val_AUC: 0.7526 - val_AUC_PR: 0.4906 - val_loss: 0.0544 - learning_rate: 1.0000e-05
# Epoch 223/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6780 - AUC_PR: 0.3798 - loss: 0.2106 - val_AUC: 0.7524 - val_AUC_PR: 0.4910 - val_loss: 0.0544 - learning_rate: 1.0000e-05
# Epoch 224/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6861 - AUC_PR: 0.3811 - loss: 0.2084 - val_AUC: 0.7529 - val_AUC_PR: 0.4913 - val_loss: 0.0544 - learning_rate: 1.0000e-05
# Epoch 225/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6859 - AUC_PR: 0.3803 - loss: 0.2074 - val_AUC: 0.7531 - val_AUC_PR: 0.4921 - val_loss: 0.0544 - learning_rate: 1.0000e-05
# Epoch 226/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6843 - AUC_PR: 0.3772 - loss: 0.2091 - val_AUC: 0.7532 - val_AUC_PR: 0.4925 - val_loss: 0.0544 - learning_rate: 1.0000e-05
# Epoch 227/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6803 - AUC_PR: 0.3770 - loss: 0.2111 - val_AUC: 0.7535 - val_AUC_PR: 0.4927 - val_loss: 0.0543 - learning_rate: 1.0000e-05
# Epoch 228/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6866 - AUC_PR: 0.3863 - loss: 0.2070 - val_AUC: 0.7539 - val_AUC_PR: 0.4931 - val_loss: 0.0543 - learning_rate: 1.0000e-05
# Epoch 229/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6845 - AUC_PR: 0.3815 - loss: 0.2079 - val_AUC: 0.7540 - val_AUC_PR: 0.4927 - val_loss: 0.0543 - learning_rate: 1.0000e-05
# Epoch 230/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6867 - AUC_PR: 0.3869 - loss: 0.2061 - val_AUC: 0.7544 - val_AUC_PR: 0.4935 - val_loss: 0.0543 - learning_rate: 1.0000e-05
# Epoch 231/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6912 - AUC_PR: 0.3861 - loss: 0.2049 - val_AUC: 0.7552 - val_AUC_PR: 0.4939 - val_loss: 0.0542 - learning_rate: 1.0000e-05
# Epoch 232/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6853 - AUC_PR: 0.3833 - loss: 0.2073 - val_AUC: 0.7554 - val_AUC_PR: 0.4946 - val_loss: 0.0542 - learning_rate: 1.0000e-05
# Epoch 233/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6875 - AUC_PR: 0.3906 - loss: 0.2058 - val_AUC: 0.7556 - val_AUC_PR: 0.4949 - val_loss: 0.0542 - learning_rate: 1.0000e-05
# Epoch 234/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6798 - AUC_PR: 0.3745 - loss: 0.2106 - val_AUC: 0.7560 - val_AUC_PR: 0.4953 - val_loss: 0.0542 - learning_rate: 1.0000e-05
# Epoch 235/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6938 - AUC_PR: 0.3904 - loss: 0.2029 - val_AUC: 0.7562 - val_AUC_PR: 0.4953 - val_loss: 0.0542 - learning_rate: 1.0000e-05
# Epoch 236/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6867 - AUC_PR: 0.3822 - loss: 0.2072 - val_AUC: 0.7563 - val_AUC_PR: 0.4957 - val_loss: 0.0542 - learning_rate: 1.0000e-05
# Epoch 237/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6897 - AUC_PR: 0.3901 - loss: 0.2038 - val_AUC: 0.7565 - val_AUC_PR: 0.4957 - val_loss: 0.0541 - learning_rate: 1.0000e-05
# Epoch 238/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6908 - AUC_PR: 0.3898 - loss: 0.2042 - val_AUC: 0.7564 - val_AUC_PR: 0.4961 - val_loss: 0.0541 - learning_rate: 1.0000e-05
# Epoch 239/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6918 - AUC_PR: 0.3870 - loss: 0.2046 - val_AUC: 0.7564 - val_AUC_PR: 0.4958 - val_loss: 0.0541 - learning_rate: 1.0000e-05
# Epoch 240/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6937 - AUC_PR: 0.3883 - loss: 0.2019 - val_AUC: 0.7567 - val_AUC_PR: 0.4961 - val_loss: 0.0541 - learning_rate: 1.0000e-05
# Epoch 241/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6901 - AUC_PR: 0.3887 - loss: 0.2030 - val_AUC: 0.7570 - val_AUC_PR: 0.4968 - val_loss: 0.0541 - learning_rate: 1.0000e-05
# Epoch 242/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6924 - AUC_PR: 0.3902 - loss: 0.2029 - val_AUC: 0.7577 - val_AUC_PR: 0.4973 - val_loss: 0.0540 - learning_rate: 1.0000e-05
# Epoch 243/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6979 - AUC_PR: 0.3976 - loss: 0.1995 - val_AUC: 0.7576 - val_AUC_PR: 0.4975 - val_loss: 0.0540 - learning_rate: 1.0000e-05
# Epoch 244/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6925 - AUC_PR: 0.3913 - loss: 0.2027 - val_AUC: 0.7578 - val_AUC_PR: 0.4980 - val_loss: 0.0540 - learning_rate: 1.0000e-05
# Epoch 245/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6888 - AUC_PR: 0.3872 - loss: 0.2037 - val_AUC: 0.7578 - val_AUC_PR: 0.4982 - val_loss: 0.0540 - learning_rate: 1.0000e-05
# Epoch 246/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6898 - AUC_PR: 0.3894 - loss: 0.2028 - val_AUC: 0.7583 - val_AUC_PR: 0.4988 - val_loss: 0.0540 - learning_rate: 1.0000e-05
# Epoch 247/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6918 - AUC_PR: 0.3883 - loss: 0.2027 - val_AUC: 0.7586 - val_AUC_PR: 0.4989 - val_loss: 0.0540 - learning_rate: 1.0000e-05
# Epoch 248/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6900 - AUC_PR: 0.3905 - loss: 0.2023 - val_AUC: 0.7587 - val_AUC_PR: 0.4990 - val_loss: 0.0540 - learning_rate: 1.0000e-05
# Epoch 249/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6973 - AUC_PR: 0.3938 - loss: 0.2002 - val_AUC: 0.7591 - val_AUC_PR: 0.4999 - val_loss: 0.0540 - learning_rate: 1.0000e-05
# Epoch 250/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6992 - AUC_PR: 0.3973 - loss: 0.1989 - val_AUC: 0.7591 - val_AUC_PR: 0.4994 - val_loss: 0.0539 - learning_rate: 1.0000e-05
# Epoch 251/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6919 - AUC_PR: 0.3921 - loss: 0.2013 - val_AUC: 0.7594 - val_AUC_PR: 0.4998 - val_loss: 0.0539 - learning_rate: 1.0000e-05
# Epoch 252/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6973 - AUC_PR: 0.3984 - loss: 0.2004 - val_AUC: 0.7596 - val_AUC_PR: 0.5003 - val_loss: 0.0539 - learning_rate: 1.0000e-05
# Epoch 253/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6940 - AUC_PR: 0.3921 - loss: 0.2014 - val_AUC: 0.7595 - val_AUC_PR: 0.5003 - val_loss: 0.0539 - learning_rate: 1.0000e-05
# Epoch 254/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6960 - AUC_PR: 0.4021 - loss: 0.2004 - val_AUC: 0.7597 - val_AUC_PR: 0.5004 - val_loss: 0.0539 - learning_rate: 1.0000e-05
# Epoch 255/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6976 - AUC_PR: 0.4004 - loss: 0.1980 - val_AUC: 0.7601 - val_AUC_PR: 0.5009 - val_loss: 0.0538 - learning_rate: 1.0000e-05
# Epoch 256/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6937 - AUC_PR: 0.3919 - loss: 0.2009 - val_AUC: 0.7601 - val_AUC_PR: 0.5010 - val_loss: 0.0538 - learning_rate: 1.0000e-05
# Epoch 257/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6952 - AUC_PR: 0.3880 - loss: 0.2006 - val_AUC: 0.7606 - val_AUC_PR: 0.5013 - val_loss: 0.0538 - learning_rate: 1.0000e-05
# Epoch 258/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6975 - AUC_PR: 0.3917 - loss: 0.2003 - val_AUC: 0.7605 - val_AUC_PR: 0.5017 - val_loss: 0.0538 - learning_rate: 1.0000e-05
# Epoch 259/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6964 - AUC_PR: 0.3958 - loss: 0.1997 - val_AUC: 0.7608 - val_AUC_PR: 0.5021 - val_loss: 0.0538 - learning_rate: 1.0000e-05
# Epoch 260/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6946 - AUC_PR: 0.3944 - loss: 0.1996 - val_AUC: 0.7609 - val_AUC_PR: 0.5022 - val_loss: 0.0538 - learning_rate: 1.0000e-05
# Epoch 261/2000
# 47/47 - 0s - 3ms/step - AUC: 0.6947 - AUC_PR: 0.3903 - loss: 0.2001 - val_AUC: 0.7610 - val_AUC_PR: 0.5026 - val_loss: 0.0538 - learning_rate: 1.0000e-05
# Epoch 262/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6946 - AUC_PR: 0.3949 - loss: 0.2001 - val_AUC: 0.7613 - val_AUC_PR: 0.5026 - val_loss: 0.0538 - learning_rate: 1.0000e-05
# Epoch 263/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6989 - AUC_PR: 0.3960 - loss: 0.1986 - val_AUC: 0.7613 - val_AUC_PR: 0.5034 - val_loss: 0.0538 - learning_rate: 1.0000e-05
# Epoch 264/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7001 - AUC_PR: 0.4014 - loss: 0.1983 - val_AUC: 0.7614 - val_AUC_PR: 0.5038 - val_loss: 0.0537 - learning_rate: 1.0000e-05
# Epoch 265/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6996 - AUC_PR: 0.3969 - loss: 0.1989 - val_AUC: 0.7616 - val_AUC_PR: 0.5036 - val_loss: 0.0537 - learning_rate: 1.0000e-05
# Epoch 266/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6994 - AUC_PR: 0.3926 - loss: 0.1980 - val_AUC: 0.7618 - val_AUC_PR: 0.5040 - val_loss: 0.0537 - learning_rate: 1.0000e-05
# Epoch 267/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7021 - AUC_PR: 0.4016 - loss: 0.1966 - val_AUC: 0.7621 - val_AUC_PR: 0.5042 - val_loss: 0.0537 - learning_rate: 1.0000e-05
# Epoch 268/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6982 - AUC_PR: 0.4004 - loss: 0.1969 - val_AUC: 0.7624 - val_AUC_PR: 0.5046 - val_loss: 0.0537 - learning_rate: 1.0000e-05
# Epoch 269/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7048 - AUC_PR: 0.4106 - loss: 0.1957 - val_AUC: 0.7623 - val_AUC_PR: 0.5051 - val_loss: 0.0537 - learning_rate: 1.0000e-05
# Epoch 270/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7075 - AUC_PR: 0.4047 - loss: 0.1945 - val_AUC: 0.7628 - val_AUC_PR: 0.5052 - val_loss: 0.0536 - learning_rate: 1.0000e-05
# Epoch 271/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7061 - AUC_PR: 0.4032 - loss: 0.1945 - val_AUC: 0.7628 - val_AUC_PR: 0.5055 - val_loss: 0.0536 - learning_rate: 1.0000e-05
# Epoch 272/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6994 - AUC_PR: 0.3971 - loss: 0.1975 - val_AUC: 0.7629 - val_AUC_PR: 0.5059 - val_loss: 0.0536 - learning_rate: 1.0000e-05
# Epoch 273/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7023 - AUC_PR: 0.4020 - loss: 0.1965 - val_AUC: 0.7631 - val_AUC_PR: 0.5061 - val_loss: 0.0536 - learning_rate: 1.0000e-05
# Epoch 274/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6968 - AUC_PR: 0.3893 - loss: 0.1982 - val_AUC: 0.7633 - val_AUC_PR: 0.5062 - val_loss: 0.0536 - learning_rate: 1.0000e-05
# Epoch 275/2000
# 47/47 - 0s - 2ms/step - AUC: 0.6967 - AUC_PR: 0.3892 - loss: 0.1998 - val_AUC: 0.7634 - val_AUC_PR: 0.5065 - val_loss: 0.0536 - learning_rate: 1.0000e-05
# Epoch 276/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7008 - AUC_PR: 0.3996 - loss: 0.1953 - val_AUC: 0.7638 - val_AUC_PR: 0.5066 - val_loss: 0.0536 - learning_rate: 1.0000e-05
# Epoch 277/2000
# ...
# Epoch 289/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7083 - AUC_PR: 0.4051 - loss: 0.1919 - val_AUC: 0.7652 - val_AUC_PR: 0.5096 - val_loss: 0.0534 - learning_rate: 1.0000e-05
# Epoch 290/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7051 - AUC_PR: 0.4053 - loss: 0.1923 - val_AUC: 0.7655 - val_AUC_PR: 0.5099 - val_loss: 0.0534 - learning_rate: 1.0000e-05
# Epoch 291/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7091 - AUC_PR: 0.4055 - loss: 0.1919 - val_AUC: 0.7658 - val_AUC_PR: 0.5098 - val_loss: 0.0534 - learning_rate: 1.0000e-05
# Epoch 292/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7095 - AUC_PR: 0.4052 - loss: 0.1917 - val_AUC: 0.7659 - val_AUC_PR: 0.5100 - val_loss: 0.0534 - learning_rate: 1.0000e-05
# Epoch 293/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7071 - AUC_PR: 0.4059 - loss: 0.1924 - val_AUC: 0.7659 - val_AUC_PR: 0.5099 - val_loss: 0.0534 - learning_rate: 1.0000e-05
# Epoch 294/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7147 - AUC_PR: 0.4117 - loss: 0.1884 - val_AUC: 0.7660 - val_AUC_PR: 0.5096 - val_loss: 0.0534 - learning_rate: 1.0000e-05
# Epoch 295/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7065 - AUC_PR: 0.4045 - loss: 0.1934 - val_AUC: 0.7661 - val_AUC_PR: 0.5098 - val_loss: 0.0534 - learning_rate: 1.0000e-05
# Epoch 296/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7092 - AUC_PR: 0.4068 - loss: 0.1918 - val_AUC: 0.7660 - val_AUC_PR: 0.5095 - val_loss: 0.0534 - learning_rate: 1.0000e-05
# Epoch 297/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7112 - AUC_PR: 0.4095 - loss: 0.1924 - val_AUC: 0.7660 - val_AUC_PR: 0.5095 - val_loss: 0.0534 - learning_rate: 1.0000e-05
# Epoch 298/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7087 - AUC_PR: 0.4054 - loss: 0.1925 - val_AUC: 0.7664 - val_AUC_PR: 0.5103 - val_loss: 0.0533 - learning_rate: 1.0000e-05
# Epoch 299/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7100 - AUC_PR: 0.4064 - loss: 0.1908 - val_AUC: 0.7663 - val_AUC_PR: 0.5103 - val_loss: 0.0533 - learning_rate: 1.0000e-05
# Epoch 300/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7082 - AUC_PR: 0.4070 - loss: 0.1919 - val_AUC: 0.7666 - val_AUC_PR: 0.5107 - val_loss: 0.0533 - learning_rate: 1.0000e-05
# Epoch 301/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7080 - AUC_PR: 0.4149 - loss: 0.1918 - val_AUC: 0.7669 - val_AUC_PR: 0.5113 - val_loss: 0.0533 - learning_rate: 1.0000e-05
# Epoch 302/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7072 - AUC_PR: 0.4041 - loss: 0.1914 - val_AUC: 0.7667 - val_AUC_PR: 0.5109 - val_loss: 0.0533 - learning_rate: 1.0000e-05
# Epoch 303/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7069 - AUC_PR: 0.4050 - loss: 0.1921 - val_AUC: 0.7668 - val_AUC_PR: 0.5116 - val_loss: 0.0533 - learning_rate: 1.0000e-05
# Epoch 304/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7121 - AUC_PR: 0.4151 - loss: 0.1892 - val_AUC: 0.7669 - val_AUC_PR: 0.5117 - val_loss: 0.0533 - learning_rate: 1.0000e-05
# Epoch 305/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7139 - AUC_PR: 0.4151 - loss: 0.1886 - val_AUC: 0.7669 - val_AUC_PR: 0.5119 - val_loss: 0.0533 - learning_rate: 1.0000e-05
# Epoch 306/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7097 - AUC_PR: 0.4086 - loss: 0.1915 - val_AUC: 0.7670 - val_AUC_PR: 0.5121 - val_loss: 0.0533 - learning_rate: 1.0000e-05
# Epoch 307/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7091 - AUC_PR: 0.4127 - loss: 0.1910 - val_AUC: 0.7675 - val_AUC_PR: 0.5122 - val_loss: 0.0532 - learning_rate: 1.0000e-05
# Epoch 308/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7071 - AUC_PR: 0.4079 - loss: 0.1901 - val_AUC: 0.7675 - val_AUC_PR: 0.5124 - val_loss: 0.0532 - learning_rate: 1.0000e-05
# Epoch 309/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7076 - AUC_PR: 0.4061 - loss: 0.1907 - val_AUC: 0.7675 - val_AUC_PR: 0.5123 - val_loss: 0.0532 - learning_rate: 1.0000e-05
# Epoch 310/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7143 - AUC_PR: 0.4132 - loss: 0.1897 - val_AUC: 0.7676 - val_AUC_PR: 0.5127 - val_loss: 0.0532 - learning_rate: 1.0000e-05
# Epoch 311/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7139 - AUC_PR: 0.4142 - loss: 0.1874 - val_AUC: 0.7676 - val_AUC_PR: 0.5127 - val_loss: 0.0532 - learning_rate: 1.0000e-05
# Epoch 312/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7135 - AUC_PR: 0.4167 - loss: 0.1892 - val_AUC: 0.7676 - val_AUC_PR: 0.5127 - val_loss: 0.0532 - learning_rate: 1.0000e-05
# Epoch 313/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7150 - AUC_PR: 0.4138 - loss: 0.1882 - val_AUC: 0.7678 - val_AUC_PR: 0.5131 - val_loss: 0.0532 - learning_rate: 1.0000e-05
# Epoch 314/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7111 - AUC_PR: 0.4161 - loss: 0.1894 - val_AUC: 0.7678 - val_AUC_PR: 0.5130 - val_loss: 0.0532 - learning_rate: 1.0000e-05
# Epoch 315/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7164 - AUC_PR: 0.4175 - loss: 0.1868 - val_AUC: 0.7679 - val_AUC_PR: 0.5133 - val_loss: 0.0532 - learning_rate: 1.0000e-05
# Epoch 316/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7108 - AUC_PR: 0.4105 - loss: 0.1900 - val_AUC: 0.7678 - val_AUC_PR: 0.5132 - val_loss: 0.0532 - learning_rate: 1.0000e-05
# Epoch 317/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7147 - AUC_PR: 0.4131 - loss: 0.1877 - val_AUC: 0.7681 - val_AUC_PR: 0.5131 - val_loss: 0.0531 - learning_rate: 1.0000e-05
# Epoch 318/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7146 - AUC_PR: 0.4190 - loss: 0.1868 - val_AUC: 0.7682 - val_AUC_PR: 0.5133 - val_loss: 0.0531 - learning_rate: 1.0000e-05
# Epoch 319/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7084 - AUC_PR: 0.4111 - loss: 0.1888 - val_AUC: 0.7683 - val_AUC_PR: 0.5131 - val_loss: 0.0531 - learning_rate: 1.0000e-05
# Epoch 320/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7109 - AUC_PR: 0.4157 - loss: 0.1880 - val_AUC: 0.7684 - val_AUC_PR: 0.5135 - val_loss: 0.0531 - learning_rate: 1.0000e-05
# Epoch 321/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7142 - AUC_PR: 0.4154 - loss: 0.1870 - val_AUC: 0.7686 - val_AUC_PR: 0.5138 - val_loss: 0.0531 - learning_rate: 1.0000e-05
# Epoch 322/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7128 - AUC_PR: 0.4184 - loss: 0.1878 - val_AUC: 0.7689 - val_AUC_PR: 0.5144 - val_loss: 0.0531 - learning_rate: 1.0000e-05
# Epoch 323/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7150 - AUC_PR: 0.4198 - loss: 0.1875 - val_AUC: 0.7690 - val_AUC_PR: 0.5143 - val_loss: 0.0531 - learning_rate: 1.0000e-05
# Epoch 324/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7109 - AUC_PR: 0.4182 - loss: 0.1877 - val_AUC: 0.7690 - val_AUC_PR: 0.5149 - val_loss: 0.0531 - learning_rate: 1.0000e-05
# Epoch 325/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7156 - AUC_PR: 0.4173 - loss: 0.1873 - val_AUC: 0.7689 - val_AUC_PR: 0.5149 - val_loss: 0.0530 - learning_rate: 1.0000e-05
# Epoch 326/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7162 - AUC_PR: 0.4226 - loss: 0.1863 - val_AUC: 0.7689 - val_AUC_PR: 0.5147 - val_loss: 0.0530 - learning_rate: 1.0000e-05
# Epoch 327/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7162 - AUC_PR: 0.4171 - loss: 0.1860 - val_AUC: 0.7688 - val_AUC_PR: 0.5151 - val_loss: 0.0530 - learning_rate: 1.0000e-05
# Epoch 328/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7178 - AUC_PR: 0.4226 - loss: 0.1855 - val_AUC: 0.7691 - val_AUC_PR: 0.5151 - val_loss: 0.0530 - learning_rate: 1.0000e-05
# Epoch 329/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7195 - AUC_PR: 0.4266 - loss: 0.1845 - val_AUC: 0.7691 - val_AUC_PR: 0.5155 - val_loss: 0.0530 - learning_rate: 1.0000e-05
# Epoch 330/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7175 - AUC_PR: 0.4209 - loss: 0.1856 - val_AUC: 0.7691 - val_AUC_PR: 0.5151 - val_loss: 0.0530 - learning_rate: 1.0000e-05
# Epoch 331/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7192 - AUC_PR: 0.4208 - loss: 0.1846 - val_AUC: 0.7692 - val_AUC_PR: 0.5149 - val_loss: 0.0530 - learning_rate: 1.0000e-05
# Epoch 332/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7199 - AUC_PR: 0.4253 - loss: 0.1839 - val_AUC: 0.7693 - val_AUC_PR: 0.5152 - val_loss: 0.0530 - learning_rate: 1.0000e-05
# Epoch 333/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7190 - AUC_PR: 0.4286 - loss: 0.1844 - val_AUC: 0.7691 - val_AUC_PR: 0.5152 - val_loss: 0.0530 - learning_rate: 1.0000e-05
# Epoch 334/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7167 - AUC_PR: 0.4221 - loss: 0.1857 - val_AUC: 0.7693 - val_AUC_PR: 0.5152 - val_loss: 0.0530 - learning_rate: 1.0000e-05
# Epoch 335/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7172 - AUC_PR: 0.4210 - loss: 0.1849 - val_AUC: 0.7694 - val_AUC_PR: 0.5154 - val_loss: 0.0530 - learning_rate: 1.0000e-05
# Epoch 336/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7183 - AUC_PR: 0.4210 - loss: 0.1855 - val_AUC: 0.7695 - val_AUC_PR: 0.5159 - val_loss: 0.0529 - learning_rate: 1.0000e-05
# Epoch 337/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7198 - AUC_PR: 0.4258 - loss: 0.1840 - val_AUC: 0.7697 - val_AUC_PR: 0.5153 - val_loss: 0.0529 - learning_rate: 1.0000e-05
# Epoch 338/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7200 - AUC_PR: 0.4265 - loss: 0.1842 - val_AUC: 0.7697 - val_AUC_PR: 0.5155 - val_loss: 0.0529 - learning_rate: 1.0000e-05
# Epoch 339/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7219 - AUC_PR: 0.4245 - loss: 0.1830 - val_AUC: 0.7697 - val_AUC_PR: 0.5154 - val_loss: 0.0529 - learning_rate: 1.0000e-05
# Epoch 340/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7207 - AUC_PR: 0.4207 - loss: 0.1837 - val_AUC: 0.7699 - val_AUC_PR: 0.5158 - val_loss: 0.0529 - learning_rate: 1.0000e-05
# Epoch 341/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7261 - AUC_PR: 0.4372 - loss: 0.1816 - val_AUC: 0.7699 - val_AUC_PR: 0.5159 - val_loss: 0.0529 - learning_rate: 1.0000e-05
# Epoch 342/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7179 - AUC_PR: 0.4206 - loss: 0.1843 - val_AUC: 0.7698 - val_AUC_PR: 0.5159 - val_loss: 0.0529 - learning_rate: 1.0000e-05
# Epoch 343/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7240 - AUC_PR: 0.4268 - loss: 0.1819 - val_AUC: 0.7702 - val_AUC_PR: 0.5160 - val_loss: 0.0529 - learning_rate: 1.0000e-05
# Epoch 344/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7177 - AUC_PR: 0.4229 - loss: 0.1841 - val_AUC: 0.7703 - val_AUC_PR: 0.5165 - val_loss: 0.0529 - learning_rate: 1.0000e-05
# Epoch 345/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7207 - AUC_PR: 0.4203 - loss: 0.1834 - val_AUC: 0.7704 - val_AUC_PR: 0.5168 - val_loss: 0.0528 - learning_rate: 1.0000e-05
# Epoch 346/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7196 - AUC_PR: 0.4217 - loss: 0.1837 - val_AUC: 0.7705 - val_AUC_PR: 0.5167 - val_loss: 0.0528 - learning_rate: 1.0000e-05
# Epoch 347/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7163 - AUC_PR: 0.4206 - loss: 0.1849 - val_AUC: 0.7709 - val_AUC_PR: 0.5171 - val_loss: 0.0528 - learning_rate: 1.0000e-05
# Epoch 348/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7206 - AUC_PR: 0.4302 - loss: 0.1828 - val_AUC: 0.7710 - val_AUC_PR: 0.5171 - val_loss: 0.0528 - learning_rate: 1.0000e-05
# Epoch 349/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7232 - AUC_PR: 0.4325 - loss: 0.1821 - val_AUC: 0.7709 - val_AUC_PR: 0.5176 - val_loss: 0.0528 - learning_rate: 1.0000e-05
# Epoch 350/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7213 - AUC_PR: 0.4282 - loss: 0.1839 - val_AUC: 0.7709 - val_AUC_PR: 0.5180 - val_loss: 0.0528 - learning_rate: 1.0000e-05
# Epoch 351/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7210 - AUC_PR: 0.4243 - loss: 0.1830 - val_AUC: 0.7711 - val_AUC_PR: 0.5181 - val_loss: 0.0528 - learning_rate: 1.0000e-05
# Epoch 352/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7211 - AUC_PR: 0.4308 - loss: 0.1838 - val_AUC: 0.7710 - val_AUC_PR: 0.5185 - val_loss: 0.0528 - learning_rate: 1.0000e-05
# Epoch 353/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7253 - AUC_PR: 0.4264 - loss: 0.1814 - val_AUC: 0.7710 - val_AUC_PR: 0.5187 - val_loss: 0.0528 - learning_rate: 1.0000e-05
# Epoch 354/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7256 - AUC_PR: 0.4303 - loss: 0.1812 - val_AUC: 0.7710 - val_AUC_PR: 0.5183 - val_loss: 0.0528 - learning_rate: 1.0000e-05
# Epoch 355/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7220 - AUC_PR: 0.4208 - loss: 0.1821 - val_AUC: 0.7710 - val_AUC_PR: 0.5184 - val_loss: 0.0528 - learning_rate: 1.0000e-05
# Epoch 356/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7230 - AUC_PR: 0.4336 - loss: 0.1818 - val_AUC: 0.7709 - val_AUC_PR: 0.5186 - val_loss: 0.0528 - learning_rate: 1.0000e-05
# Epoch 357/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7241 - AUC_PR: 0.4361 - loss: 0.1814 - val_AUC: 0.7709 - val_AUC_PR: 0.5186 - val_loss: 0.0527 - learning_rate: 1.0000e-05
# Epoch 358/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7231 - AUC_PR: 0.4223 - loss: 0.1822 - val_AUC: 0.7708 - val_AUC_PR: 0.5186 - val_loss: 0.0527 - learning_rate: 1.0000e-05
# Epoch 359/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7196 - AUC_PR: 0.4234 - loss: 0.1833 - val_AUC: 0.7711 - val_AUC_PR: 0.5190 - val_loss: 0.0527 - learning_rate: 1.0000e-05
# Epoch 360/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7225 - AUC_PR: 0.4292 - loss: 0.1821 - val_AUC: 0.7711 - val_AUC_PR: 0.5187 - val_loss: 0.0527 - learning_rate: 1.0000e-05
# Epoch 361/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7264 - AUC_PR: 0.4391 - loss: 0.1807 - val_AUC: 0.7709 - val_AUC_PR: 0.5192 - val_loss: 0.0527 - learning_rate: 1.0000e-05
# Epoch 362/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7260 - AUC_PR: 0.4302 - loss: 0.1810 - val_AUC: 0.7709 - val_AUC_PR: 0.5190 - val_loss: 0.0527 - learning_rate: 1.0000e-05
# Epoch 363/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7192 - AUC_PR: 0.4234 - loss: 0.1825 - val_AUC: 0.7713 - val_AUC_PR: 0.5194 - val_loss: 0.0527 - learning_rate: 1.0000e-05
# Epoch 364/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7259 - AUC_PR: 0.4273 - loss: 0.1801 - val_AUC: 0.7714 - val_AUC_PR: 0.5195 - val_loss: 0.0527 - learning_rate: 1.0000e-05
# Epoch 365/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7213 - AUC_PR: 0.4335 - loss: 0.1816 - val_AUC: 0.7716 - val_AUC_PR: 0.5194 - val_loss: 0.0527 - learning_rate: 1.0000e-05
# Epoch 366/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7270 - AUC_PR: 0.4300 - loss: 0.1804 - val_AUC: 0.7715 - val_AUC_PR: 0.5189 - val_loss: 0.0527 - learning_rate: 1.0000e-05
# Epoch 367/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7256 - AUC_PR: 0.4314 - loss: 0.1803 - val_AUC: 0.7714 - val_AUC_PR: 0.5190 - val_loss: 0.0527 - learning_rate: 1.0000e-05
# Epoch 368/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7260 - AUC_PR: 0.4410 - loss: 0.1798 - val_AUC: 0.7716 - val_AUC_PR: 0.5194 - val_loss: 0.0527 - learning_rate: 1.0000e-05
# Epoch 369/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7255 - AUC_PR: 0.4337 - loss: 0.1802 - val_AUC: 0.7713 - val_AUC_PR: 0.5198 - val_loss: 0.0527 - learning_rate: 1.0000e-05
# Epoch 370/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7245 - AUC_PR: 0.4335 - loss: 0.1804 - val_AUC: 0.7716 - val_AUC_PR: 0.5202 - val_loss: 0.0526 - learning_rate: 1.0000e-05
# Epoch 371/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7272 - AUC_PR: 0.4334 - loss: 0.1798 - val_AUC: 0.7716 - val_AUC_PR: 0.5198 - val_loss: 0.0526 - learning_rate: 1.0000e-05
# Epoch 372/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7257 - AUC_PR: 0.4340 - loss: 0.1795 - val_AUC: 0.7715 - val_AUC_PR: 0.5198 - val_loss: 0.0526 - learning_rate: 1.0000e-05
# Epoch 373/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7232 - AUC_PR: 0.4356 - loss: 0.1805 - val_AUC: 0.7715 - val_AUC_PR: 0.5197 - val_loss: 0.0526 - learning_rate: 1.0000e-05
# Epoch 374/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7264 - AUC_PR: 0.4299 - loss: 0.1795 - val_AUC: 0.7716 - val_AUC_PR: 0.5196 - val_loss: 0.0526 - learning_rate: 1.0000e-05
# Epoch 375/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7232 - AUC_PR: 0.4323 - loss: 0.1806 - val_AUC: 0.7716 - val_AUC_PR: 0.5195 - val_loss: 0.0526 - learning_rate: 1.0000e-05
# Epoch 376/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7236 - AUC_PR: 0.4329 - loss: 0.1798 - val_AUC: 0.7716 - val_AUC_PR: 0.5197 - val_loss: 0.0526 - learning_rate: 1.0000e-05
# Epoch 377/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7295 - AUC_PR: 0.4402 - loss: 0.1778 - val_AUC: 0.7714 - val_AUC_PR: 0.5200 - val_loss: 0.0526 - learning_rate: 1.0000e-05
# Epoch 378/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7287 - AUC_PR: 0.4379 - loss: 0.1784 - val_AUC: 0.7714 - val_AUC_PR: 0.5197 - val_loss: 0.0526 - learning_rate: 1.0000e-05
# Epoch 379/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7273 - AUC_PR: 0.4413 - loss: 0.1783 - val_AUC: 0.7717 - val_AUC_PR: 0.5196 - val_loss: 0.0526 - learning_rate: 1.0000e-05
# Epoch 380/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7283 - AUC_PR: 0.4368 - loss: 0.1781 - val_AUC: 0.7716 - val_AUC_PR: 0.5200 - val_loss: 0.0526 - learning_rate: 1.0000e-05
# Epoch 381/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7254 - AUC_PR: 0.4373 - loss: 0.1793 - val_AUC: 0.7715 - val_AUC_PR: 0.5197 - val_loss: 0.0526 - learning_rate: 1.0000e-05
# Epoch 382/2000
# 47/47 - 0s - 2ms/step - AUC: 0.7294 - AUC_PR: 0.4384 - loss: 0.1777 - val_AUC: 0.7717 - val_AUC_PR: 0.5201 - val_loss: 0.0526 - learning_rate: 1.0000e-05

# %%
# ========= 7) Threshold selection on VAL =========
from sklearn.metrics import precision_recall_curve, roc_auc_score, average_precision_score, f1_score, confusion_matrix, classification_report

p_va = model.predict(X_va_sc, verbose=0).ravel()
p_te = model.predict(X_te_sc, verbose=0).ravel()

# (a) F1-max threshold (from validation)
prec, rec, thr = precision_recall_curve(y_va, p_va)
f1s = 2*prec*rec/(prec+rec+1e-12)
if len(thr) > 0:
    t_f1 = float(thr[np.nanargmax(f1s[:-1])])
else:
    t_f1 = 0.5

# (b) Cost-min threshold (from validation)
def expected_cost(y_true, p, th, c_fp=1.0, c_fn=10.0):
    yp = (p>=th).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, yp).ravel()
    return c_fp*fp + c_fn*fn

if len(thr) > 0:
    costs = [expected_cost(y_va, p_va, t, C_FP, C_FN) for t in thr[:-1]]
    t_cost = float(thr[int(np.argmin(costs))])
else:
    t_cost = 0.5

def report_at(th, y_true, p):
    yp = (p>=th).astype(int)
    roc = roc_auc_score(y_true, p)
    ap  = average_precision_score(y_true, p)
    cm  = confusion_matrix(y_true, yp)
    f1  = f1_score(y_true, yp)
    return roc, ap, f1, cm, classification_report(y_true, yp, digits=3)

print("\n===== VAL performance =====")
roc_v, ap_v, f1_v, cm_v, cr_v = report_at(t_f1, y_va, p_va)
print(f"[VAL @ F1-thr={t_f1:.3f}] ROC-AUC={roc_v:.3f} | AUC-PR={ap_v:.3f} | F1={f1_v:.3f}\n{cm_v}\n{cr_v}")

roc_v2, ap_v2, f1_v2, cm_v2, cr_v2 = report_at(t_cost, y_va, p_va)
print(f"[VAL @ Cost-thr={t_cost:.3f}] ROC-AUC={roc_v2:.3f} | AUC-PR={ap_v2:.3f} | F1={f1_v2:.3f}\n{cm_v2}\n{cr_v2}")

# ========= 8) FINAL TEST (ใช้ threshold จาก VAL เท่านั้น) =========
print("\n===== TEST performance =====")
roc_t, ap_t, f1_t, cm_t, cr_t = report_at(t_f1, y_te, p_te)
print(f"[TEST @ F1-thr={t_f1:.3f}] ROC-AUC={roc_t:.3f} | AUC-PR={ap_t:.3f} | F1={f1_t:.3f}\n{cm_t}\n{cr_t}")

roc_t2, ap_t2, f1_t2, cm_t2, cr_t2 = report_at(t_cost, y_te, p_te)
print(f"[TEST @ Cost-thr={t_cost:.3f}] ROC-AUC={roc_t2:.3f} | AUC-PR={ap_t2:.3f} | F1={f1_t2:.3f}\n{cm_t2}\n{cr_t2}")
# Out:
# ===== VAL performance =====
# [VAL @ F1-thr=0.345] ROC-AUC=0.772 | AUC-PR=0.521 | F1=0.537
# [[1911  425]
#  [ 264  400]]
#               precision    recall  f1-score   support
#
#            0      0.879     0.818     0.847      2336
#            1      0.485     0.602     0.537       664
#
#     accuracy                          0.770      3000
#    macro avg      0.682     0.710     0.692      3000
# weighted avg      0.791     0.770     0.779      3000
#
# [VAL @ Cost-thr=0.224] ROC-AUC=0.772 | AUC-PR=0.521 | F1=0.428
# [[ 749 1587]
#  [  51  613]]
#               precision    recall  f1-score   support
#
#            0      0.936     0.321     0.478      2336
#            1      0.279     0.923     0.428       664
#
#     accuracy                          0.454      3000
#    macro avg      0.607     0.622     0.453      3000
# weighted avg      0.791     0.454     0.467      3000
#
#
# ===== TEST performance =====
# [TEST @ F1-thr=0.345] ROC-AUC=0.747 | AUC-PR=0.505 | F1=0.502
# [[1888  449]
#  [ 290  373]]
#               precision    recall  f1-score   support
#
#            0      0.867     0.808     0.836      2337
#            1      0.454     0.563     0.502       663
#
#     accuracy                          0.754      3000
#    macro avg      0.660     0.685     0.669      3000
# weighted avg      0.776     0.754     0.763      3000
#
# [TEST @ Cost-thr=0.224] ROC-AUC=0.747 | AUC-PR=0.505 | F1=0.417
# [[ 714 1623]
#  [  61  602]]
#               precision    recall  f1-score   support
#
#            0      0.921     0.306     0.459      2337
#            1      0.271     0.908     0.417       663
#
#     accuracy                          0.439      3000
#    macro avg      0.596     0.607     0.438      3000
# weighted avg      0.777     0.439     0.450      3000

# %%
import matplotlib.pyplot as plt
# 9.3 พล็อตกราฟ Training History (Loss)
print("\n--- 9.3: Plotting Training History ---")
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(hist.history['loss'], label='Train Loss')
plt.plot(hist.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()

# 9.4 พล็อตกราฟ Training History (AUC)
plt.subplot(1, 2, 2)
plt.plot(hist.history['AUC'], label='Train AUC')
plt.plot(hist.history['val_AUC'], label='Validation AUC')
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# --- 9.3: Plotting Training History ---
